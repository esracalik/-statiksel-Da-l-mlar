# %%
import numpy as np
rastgele= np.random.rand(3,4) 
rastgele
# Out:
# array([[0.6747742 , 0.47012199, 0.0915693 , 0.55546059],
#        [0.32765091, 0.28184042, 0.72353139, 0.5549626 ],
#        [0.06802485, 0.20545807, 0.70072168, 0.56824323]])

# %%
import pandas as pd
mu = 0 
sigma = 1
n = 10000
plt.figure(figsize=(8,4), dpi = 100)
orneklem =  np.random.normal(mu, sigma, n)
plt.hist(orneklem, bins = 50)
plt.show()

# %%
v_1=[0.6747742 , 0.47012199, 0.0915693 , 0.55546059,
       0.32765091, 0.28184042, 0.72353139, 0.5549626 ,
       0.06802485, 0.20545807, 0.70072168, 0.56824323]
v_1.sort()

# %%
from scipy import stats
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4), dpi = 200)
nsample = 100
res = stats.probplot(v_1, plot=plt)
plt.title("Q-Q Çizgesi", fontdict = baslik_font)
plt.xlabel("Teorik Değerler", fontdict = eksen_font)
plt.ylabel("Örnek Veriler", fontdict = eksen_font)
plt.show()

# %%
^#grafik bize weibull dağılımı olduğunu gösteriyor.Normal dağılım söz konusudur.

# %%
import csv
with open("google.csv",'r') as dosyam:
    csv_oku=csv.reader(dosyam,delimiter=';')
    for satır in csv_oku:
        print(satır)
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume']
# ['2015-01-02,527.561584,529.815369,522.665039,523.373108,523.373108,1447563']
# ['2015-01-05,521.827332,522.894409,511.655243,512.463013,512.463013,2059840']
# ['2015-01-06,513.589966,514.761719,499.678131,500.585632,500.585632,2899940']
# ['2015-01-07,505.611847,505.855164,498.281952,499.727997,499.727997,2065054']
# ['2015-01-08,496.626526,502.101471,489.655640,501.303680,501.303680,3353582']
# ['2015-01-09,503.377991,503.537537,493.435272,494.811493,494.811493,2071371']
# ['2015-01-12,493.584869,494.618011,486.225067,491.201416,491.201416,2326771']
# ['2015-01-13,497.474182,501.602844,491.041840,494.821472,494.821472,2370490']
# ['2015-01-14,493.295654,501.852173,491.650177,499.498627,499.498627,2235721']
# ['2015-01-15,504.185760,504.295471,496.397156,500.416107,500.416107,2715836']
# ['2015-01-16,498.640991,506.798584,498.631012,506.688873,506.688873,2298293']
# ...
